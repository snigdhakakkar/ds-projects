# %%
pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-2.2.0-py2.py3-none-any.whl (12.7 MB)
#      |████████████████████████████████| 12.7 MB 8.9 MB/s eta 0:00:01    |▊                               | 296 kB 1.4 MB/s eta 0:00:10
# Requirement already satisfied: matplotlib in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (3.5.1)
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-1.1.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 17.6 MB/s eta 0:00:01
# Requirement already satisfied: future>=0.14.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (0.18.2)
# Collecting ppscore
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 4.6 MB/s  eta 0:00:01
# Collecting missingno<=0.4.2
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Collecting lz4
#   Downloading lz4-4.0.0-cp37-cp37m-macosx_10_9_x86_64.whl (90 kB)
#      |████████████████████████████████| 90 kB 8.5 MB/s  eta 0:00:01
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_10_11_x86_64.whl (85.2 MB)
#      |████████████████████████████████| 85.2 MB 192 kB/s  eta 0:00:01    |███▌                            | 9.3 MB 11.8 MB/s eta 0:00:07     |███▉                            | 10.2 MB 11.8 MB/s eta 0:00:07     |█████████████████████████▌      | 67.7 MB 33.6 MB/s eta 0:00:01     |██████████████████████████▏     | 69.8 MB 33.6 MB/s eta 0:00:01     |██████████████████████████▋     | 70.7 MB 33.6 MB/s eta 0:00:01
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 9.1 MB/s  eta 0:00:01
# Collecting statsmodels==0.12.2
#   Downloading statsmodels-0.12.2-cp37-cp37m-macosx_10_15_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 8.7 MB/s eta 0:00:01
# Collecting dash>=2.0.0
#   Downloading dash-2.3.1-py3-none-any.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 18.3 MB/s eta 0:00:01
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s  eta 0:00:01
# Collecting strsimpy
#   Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.2 MB/s eta 0:00:011
# Requirement already satisfied: plotly>=5.0.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (5.7.0)
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 29.7 MB/s eta 0:00:01
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.11-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (2.27.1)
# Requirement already satisfied: itsdangerous in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (2.1.2)
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: numpy in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (1.21.6)
# Collecting packaging<=21.0
#   Using cached packaging-21.0-py3-none-any.whl (40 kB)
# Requirement already satisfied: cycler in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (0.10.0)
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 13.2 MB/s eta 0:00:01
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: six in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (1.16.0)
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      |████████████████████████████████| 642 kB 14.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (1.3.5)
# Requirement already satisfied: xarray in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (0.20.2)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: Flask in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (2.1.1)
# Collecting scipy==1.7.3
#   Downloading scipy-1.7.3-cp37-cp37m-macosx_10_9_x86_64.whl (33.0 MB)
#      |████████████████████████████████| 33.0 MB 11.2 MB/s eta 0:00:01    |██▊                             | 2.8 MB 17.4 MB/s eta 0:00:02     |███▉                            | 4.0 MB 17.4 MB/s eta 0:00:02
# Requirement already satisfied: seaborn in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from dtale) (0.11.2)
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-macosx_10_13_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 777 kB/s eta 0:00:01
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from scikit-learn==0.24.2->dtale) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from scikit-learn==0.24.2->dtale) (0.17.0)
# Collecting patsy>=0.5
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 22.4 MB/s eta 0:00:01
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Jinja2>=3.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from Flask->dtale) (3.1.1)
# Requirement already satisfied: click>=8.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from Flask->dtale) (8.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from Flask->dtale) (3.10.0)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from Flask->dtale) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask->dtale) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->Flask->dtale) (4.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from Jinja2>=3.0->Flask->dtale) (2.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from packaging<=21.0->dtale) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from pandas->dtale) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from pandas->dtale) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp37-cp37m-macosx_10_9_x86_64.whl (421 kB)
#      |████████████████████████████████| 421 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from matplotlib->dtale) (8.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from matplotlib->dtale) (4.33.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from requests->dtale) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from requests->dtale) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from requests->dtale) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages (from requests->dtale) (2021.10.8)
# Building wheels for collected packages: dash-colorscales, dash-daq, ppscore
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62598 sha256=17707d1eb4f1e570fd99a829d120e42e90c36b8cb7dafe42e2160a662aaf2ff0
#   Stored in directory: /Users/snigdhakakkar/Library/Caches/pip/wheels/2f/22/7e/183ba2af565e3eb955021fbb4fe8fe4a6b1ed8ae3e5c03236a
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669701 sha256=8497cf3a3b3aa868c6618f314f06b9eab68abc4edc58e1972700a775bfaef2c5
#   Stored in directory: /Users/snigdhakakkar/Library/Caches/pip/wheels/fe/54/53/a8d448db5592874db4313240571ca2c069e55f6a6b29bf5847
#   Building wheel for ppscore (setup.py) ... done
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13050 sha256=3efecc5477dc4dade246517c82c80edd7031575e2ddf8b58330e87ea200776d7
#   Stored in directory: /Users/snigdhakakkar/Library/Caches/pip/wheels/d2/3c/58/2ff786414b21713edc6f4fdb54fdee89ac37bca5edd1f60634
# Successfully built dash-colorscales dash-daq ppscore
# Installing collected packages: packaging, brotli, scipy, Flask-Compress, dash-table, dash-html-components, dash-core-components, scikit-learn, patsy, et-xmlfile, dash, xlrd, strsimpy, statsmodels, squarify, ppscore, openpyxl, networkx, missingno, lz4, kaleido, flask-ngrok, dash-daq, dash-colorscales, dash-bootstrap-components, dtale
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.6.2
#     Uninstalling scipy-1.6.2:
#       Successfully uninstalled scipy-1.6.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# Successfully installed Flask-Compress-1.11 brotli-1.0.9 dash-2.3.1 dash-bootstrap-components-1.1.0 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-2.2.0 et-xmlfile-1.1.0 flask-ngrok-0.0.25 kaleido-0.2.1 lz4-4.0.0 missingno-0.4.2 networkx-2.6.3 openpyxl-3.0.9 packaging-21.0 patsy-0.5.2 ppscore-1.2.0 scikit-learn-0.24.2 scipy-1.7.3 squarify-0.4.3 statsmodels-0.12.2 strsimpy-0.2.1 xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
df=sns.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
import dtale

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://snigdhas-MacBook-Air.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/views.py", line 121, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/views.py", line 2680, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/column_analysis.py", line 137, in build
#     return_data, code = self.analysis.build(self)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/column_analysis.py", line 446, in build
#     hist = self.build_hist(s, code)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/column_analysis.py", line 499, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/generic.py", line 5487, in __getattr__
#     return object.__getattribute__(self, name)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/accessor.py", line 181, in __get__
#     accessor_obj = self._accessor(obj)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/strings/accessor.py", line 168, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/strings/accessor.py", line 225, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!
# 2022-04-25 14:04:38,218 - ERROR    - Exception occurred while processing request: Can only use .str accessor with string values!
# Traceback (most recent call last):
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/views.py", line 121, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/views.py", line 2680, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/column_analysis.py", line 137, in build
#     return_data, code = self.analysis.build(self)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/column_analysis.py", line 446, in build
#     hist = self.build_hist(s, code)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/dtale/column_analysis.py", line 499, in build_hist
#     pd.value_counts(s.str.split(expand=True).stack())
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/generic.py", line 5487, in __getattr__
#     return object.__getattribute__(self, name)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/accessor.py", line 181, in __get__
#     accessor_obj = self._accessor(obj)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/strings/accessor.py", line 168, in __init__
#     self._inferred_dtype = self._validate(data)
#   File "/Users/snigdhakakkar/opt/anaconda2/envs/tf/lib/python3.7/site-packages/pandas/core/strings/accessor.py", line 225, in _validate
#     raise AttributeError("Can only use .str accessor with string values!")
# AttributeError: Can only use .str accessor with string values!

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['distance'])][['distance']]
chart, labels = np.histogram(s['distance'], bins=20)
import scipy.stats as sts
kde = sts.gaussian_kde(s['distance'])
kde_data = kde.pdf(np.linspace(labels.min(), labels.max()))
# main statistics
stats = df['distance'].describe().to_frame().T
charts = [
	go.Bar(x=labels[1:], y=chart, name='Histogram'),
	go.Scatter(
		x=list(range(len(kde_data))), y=kde_data, name='KDE',		yaxis='y2', xaxis='x2',		line={'shape': 'spline', 'smoothing': 0.3}, mode='lines'
	)
]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'distance Histogram (bins: 20) w/ KDE'},
    'xaxis2': {'anchor': 'y', 'overlaying': 'x', 'side': 'top'},
    'yaxis': {'side': 'left', 'title': {'text': 'Frequency'}},
    'yaxis2': {'overlaying': 'y', 'side': 'right', 'title': {'text': 'KDE'}}
}))

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
# from plotly.offline import iplot, init_notebook_mode
#
# init_notebook_mode(connected=True)
# for chart in charts:
#     chart.pop('id', None) # for some reason iplot does not like 'id'
# iplot(figure)
